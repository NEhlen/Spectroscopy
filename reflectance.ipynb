# %%
import numpy as np
import matplotlib.pyplot as plt

ref_data = "C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
spec_data = "C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"

ref_data = np.load(ref_data + "\spectrum2D.npy")
real_data = np.load(spec_data + "\spectrum2D.npy")
reflectance = real_data / ref_data

# plt.plot(real_data.sum(axis=0) / ref_data.sum(axis=0))
plt.imshow(reflectance)
# Out:
#   File "<ipython-input-1-03993e5c3693>", line 4
#     ref_data = "C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
spec_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
ref_data = np.load(ref_data + "\spectrum2D.npy")
real_data = np.load(spec_data + "\spectrum2D.npy")
reflectance = real_data / ref_data
# plt.plot(real_data.sum(axis=0) / ref_data.sum(axis=0))

plt.imshow(reflectance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\reflectance.py in <module>
#       <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=4'>5</a> ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
#       <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=5'>6</a> spec_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ----> <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=6'>7</a> ref_data = np.load(ref_data + "\spectrum2D.npy")
#       <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=7'>8</a> real_data = np.load(spec_data + "\spectrum2D.npy")
#       <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=8'>9</a> reflectance = real_data / ref_data
#
# NameError: name 'np' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
spec_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
ref_data = np.load(ref_data + "\spectrum2D.npy")
real_data = np.load(spec_data + "\spectrum2D.npy")
reflectance = real_data / ref_data
# plt.plot(real_data.sum(axis=0) / ref_data.sum(axis=0))

plt.imshow(reflectance)
# Out:
# c:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\reflectance.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   ref_data = np.load(ref_data + "\spectrum2D.npy")
# c:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\reflectance.py:7: RuntimeWarning: invalid value encountered in true_divide
#   ref_data = np.load(ref_data + "\spectrum2D.npy")

# %%
plt.savefig("reflectance_test2.png")

# %%
reflectance
# Out:
# array([[1.88244761, 1.19443996, 2.34063366, ..., 1.04492838, 0.82458257,
#         0.9884262 ],
#        [2.11052458, 2.32426384, 0.94055341, ..., 0.92041209, 1.06920771,
#         0.90880389],
#        [1.68785829, 1.17743912, 0.86848171, ..., 0.69291779, 1.94416648,
#         1.32100951],
#        ...,
#        [2.        , 0.35012216, 0.        , ..., 1.25675433, 1.9930089 ,
#         9.50146012],
#        [       inf, 4.97368421, 0.27411665, ..., 1.53698646, 1.38910965,
#         1.72478686],
#        [0.40897887, 0.25041973, 0.73534137, ..., 1.15821378, 2.42579199,
#         3.05119583]])

# %%
reflectance = real_data[850:890,:].sum(axis=0) / ref_data[850:890,:].sum(axis=0)

# %%
plt.plot(reflectance)

# %%
with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
    wavelengths = [float(line.strip()) for line in f.readlines()]

# %%
plt.plot(wavelengths, reflectance)

# %%
spec_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43"

# %%
real_data = np.load(spec_data + "\spectrum2D.npy")

# %%
plt.plot(wavelengths, reflectance)

# %%
reflectance = real_data[850:890,:].sum(axis=0) / ref_data[850:890,:].sum(axis=0)

# %%
plt.plot(wavelengths, reflectance)

# %%
plt.plot(wavelengths, reflectance)
plt.ylim(0,2)
# Out:
# (0, 2)

# %%
spec_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22"

# %%
real_data = np.load(spec_data + "\spectrum2D.npy")

# %%
reflectance = real_data[850:890,:].sum(axis=0) / ref_data[850:890,:].sum(axis=0)

# %%
plt.plot(wavelengths, reflectance)
plt.ylim(0,2)
# Out:
# (0, 2)

# %%
spec_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42"

# %%
real_data = np.load(spec_data + "\spectrum2D.npy")

# %%
reflectance = real_data[850:890,:].sum(axis=0) / ref_data[850:890,:].sum(axis=0)

# %%
plt.plot(wavelengths, reflectance)
plt.ylim(0,2)
# Out:
# (0, 2)

# %%
plt.imshow(real_data[850:890,:])

# %%
reflectance = real_data[830:940,:].sum(axis=0) / ref_data[350:940,:].sum(axis=0)

# %%
plt.imshow(real_data[850:890,:])

# %%
plt.plot(wavelengths, reflectance)
plt.ylim(0,2)
# Out:
# (0, 2)

# %%
spec_list = [
    r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
    r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
    r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
    r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
]

for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_data = np.load(ref_data + "\spectrum2D.npy")
    real_data = np.load(spec_data + "\spectrum2D.npy")
    reflectance = real_data[830:940,:].sum(axis=0) / ref_data[350:940,:].sum(axis=0)
    plt.figure()
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# c:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\reflectance.py in <module>
#       <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=12'>13</a>     with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
#      <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=13'>14</a>         wavelengths = [float(line.strip()) for line in f.readlines()]
# ---> <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=14'>15</a>     ref_data = np.load(ref_data + "\spectrum2D.npy")
#      <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=15'>16</a>     real_data = np.load(spec_data + "\spectrum2D.npy")
#      <a href='file:///c%3A/Users/Niels%20Ehlen/Documents/Programme/Spectroscopy/reflectance.py?line=16'>17</a>     reflectance = real_data[830:940,:].sum(axis=0) / ref_data[350:940,:].sum(axis=0)
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('float64'), dtype('<U15')) -> None

# %%
import matplotlib.pyplot as plt
import numpy as np
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
spec_list = [
    r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
    r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
    r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
    r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
]

for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    reflectance = real_spectrum[830:940,:].sum(axis=0) / ref_spectrum[350:940,:].sum(axis=0)
    plt.figure()
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

# %%
import matplotlib.pyplot as plt
import numpy as np
# ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
# spec_list = [
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ]
# spec_names = ["green_tight", "green_lose", "pink_lose", "yellow_tight"]

ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-43-06"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    reflectance = real_spectrum[830:940,:].sum(axis=0) / ref_spectrum[350:940,:].sum(axis=0)
    plt.figure()
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

# %%
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
# spec_list = [
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ]
# spec_names = ["green_tight", "green_lose", "pink_lose", "yellow_tight"]

ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-43-06"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    reflectance = real_spectrum[830:940,:].sum(axis=0) / ref_spectrum[350:940,:].sum(axis=0)
    plt.figure()
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

plt.savefig("reflectance_test23.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
# ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
# spec_list = [
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ]
# spec_names = ["green_tight", "green_lose", "pink_lose", "yellow_tight"]

ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-43-06"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    reflectance = real_spectrum[830:940,:].sum(axis=0) / ref_spectrum[350:940,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    reflectance = real_spectrum[830:940,:].sum(axis=0) / ref_spectrum[350:940,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    real_spectrum -= dark_spectrum
    ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[830:940,:].sum(axis=0) / ref_spectrum[350:940,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[830:940,:].sum(axis=0) / ref_spectrum[350:940,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

# %%
plt.plot(wavelengths, ref_spectrum[875:905].sum(axis=0))

# %%
plt.plot(wavelengths, real_spectrum[875:905].sum(axis=0))

# %%
reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)

# %%
plt.plot(wavelengths, reflectance)

# %%
import matplotlib.pyplot as plt
import numpy as np
# ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
# spec_list = [
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ]
# spec_names = ["green_tight", "green_lose", "pink_lose", "yellow_tight"]

ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

# %%
import matplotlib.pyplot as plt
import numpy as np
# ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
# spec_list = [
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ]
# spec_names = ["green_tight", "green_lose", "pink_lose", "yellow_tight"]

ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    real_spectrum -= dark_spectrum
    ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0,2)

# %%
import matplotlib.pyplot as plt
import numpy as np
# ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
# spec_list = [
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ]
# spec_names = ["green_tight", "green_lose", "pink_lose", "yellow_tight"]

ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    real_spectrum -= dark_spectrum
    ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(-1,4)

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(-1,4)

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 1)

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-43-06"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
# ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
# spec_list = [
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ]
# spec_names = ["green_tight", "green_lose", "pink_lose", "yellow_tight"]

ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-43-06"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 1)

plt.savefig("reflectance_test23.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
# ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-31-09"
# spec_list = [
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_21-02-42",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-43-43",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-39-22",
#     r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-12_20-34-58"
# ]
# spec_names = ["green_tight", "green_lose", "pink_lose", "yellow_tight"]

ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-43-06"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 1)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

plt.savefig("reflectance_test23.png")

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-32-43"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-51-19"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_22-24-25"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 1)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

# %%
plt.plot(wavelengths, ref_spectrum[875:905].sum(axis=0))

# %%
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-36-42"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-33-12"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 1)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

plt.savefig("reflectance_test24.png")

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-40-08"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-36-42"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-33-12"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 1)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

plt.savefig("reflectance_test24.png")

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-40-08"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-36-42"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-33-12"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 2)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

plt.savefig("reflectance_test24.png")

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-40-08"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-36-42"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-33-12"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    real_spectrum -= dark_spectrum
    ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 2)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

plt.savefig("reflectance_test24.png")

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-40-08"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-36-42"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-33-12"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 2)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

plt.savefig("reflectance_test24.png")

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-51-12"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-53-30"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-33-12"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 2)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

plt.savefig("reflectance_test25.png")

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-51-12"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-53-30"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-33-12"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 5)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

plt.savefig("reflectance_test25.png")

# %%
plt.plot(wavelengths, ref_spectrum[875:905].sum(axis=0))

# %%
plt.plot(wavelengths, real_spectrum[875:905].sum(axis=0))

# %%
ref_data = r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-51-12"
spec_list = [r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-53-30"]
dark_data= r"C:\Users\Niels Ehlen\Documents\Programme\Spectroscopy\data\spectrum_2023-12-13_23-33-12"
spec_names = ["leaf"]
for spec_data in spec_list:
    with open(spec_data + "\spectrum_wavelengths.txt", "r") as f:
        wavelengths = [float(line.strip()) for line in f.readlines()]
    ref_spectrum = np.load(ref_data + "\spectrum2D.npy")
    real_spectrum = np.load(spec_data + "\spectrum2D.npy")
    dark_spectrum = np.load(dark_data + "\spectrum2D.npy")
    # real_spectrum -= dark_spectrum
    # ref_spectrum -= dark_spectrum
    reflectance = real_spectrum[875:905,:].sum(axis=0) / ref_spectrum[875:905,:].sum(axis=0)
    plt.figure(dpi=300)
    plt.plot(wavelengths, reflectance)
    plt.ylim(0, 5)
    plt.xlabel("wavelength [nm]")
    plt.ylabel("Reflectance")

# %%
plt.plot(wavelengths, reflectance)
plt.ylim(2.3,2.5)
# Out:
# (2.3, 2.5)

# %%
plt.plot(wavelengths, reflectance)
plt.ylim(2.2,2.8)
# Out:
# (2.2, 2.8)

# %%
plt.plot(wavelengths, reflectance)
plt.ylim(2.1,2.6)
# Out:
# (2.1, 2.6)

# %%
plt.plot(wavelengths, real_spectrum[875:905].sum(axis=0))

# %%
plt.plot(wavelengths, ref_spectrum[875:905].sum(axis=0))
